# %% [markdown]
# # Video Game Sale Analysis

# %% [markdown]
# This data set is all about the Video game sales in different countries and globaly from the year when gaming has been emerged . All we know that gaming indstry has eveolved a lot in previous years and its growing rapidly these days all through the world . So here in this analysis i will analyse how its growing or not growing and which publisher , which genre has be here in the toplist till the date.

# %%
#importing libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#these libraries will help me through out my analysis by visualising through graphs.
#Seaborn is a library which uses matplotlib for plotting the graphs.

# %%
videogame = pd.read_csv("vgsales.csv")
videogame.head() # here i have tried to show the top 5 names of the dataset.
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
videogame.tail() #here i have tried to show the names present in last of the dataset
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
videogame.shape #for finding the shape of the dataset
# Out:
# (16598, 11)

# %%
videogame.info() # here we are displaying all the information present in the dataset aling with its datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
videogame.describe() #description of the dataset
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(10,7)})
# plot a histogram showing the distribution of the target values
sns.distplot(videogame.Global_Sales, bins=50)
plt.show()
# Out:
# C:\Users\akhil\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Here correlation tells us about the relation we are having with the each numerical values and according to that only it plots the graph.
corr = videogame.corr() # Finding out the correlation between the features
sns.set(rc={'figure.figsize': (10,10)}) # Plotting the heatmap of correlation between features
sns.heatmap(corr, annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Here we are finding the missing values and fixing it

# %%
#here with aproach wwe are tyring to solve the null values if any present in the Dataset.

# %%
videogame.isnull() # here we are displaying the null values
# Out:
#         Rank   Name  Platform   Year  Genre  Publisher  NA_Sales  EU_Sales  \
# 0      False  False     False  False  False      False     False     False
# 1      False  False     False  False  False      False     False     False
# 2      False  False     False  False  False      False     False     False
# 3      False  False     False  False  False      False     False     False
# 4      False  False     False  False  False      False     False     False
# ...      ...    ...       ...    ...    ...        ...       ...       ...
# 16593  False  False     False  False  False      False     False     False
# 16594  False  False     False  False  False      False     False     False
# 16595  False  False     False  False  False      False     False     False
# 16596  False  False     False  False  False      False     False     False
# 16597  False  False     False  False  False      False     False     False
#
#        JP_Sales  Other_Sales  Global_Sales
# ...

# %%
videogame.isnull().sum() #with this function we can find the null values we are having in our dataset
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
Yearof_mean = videogame.Year.mean()

# %%
print(Yearof_mean) #here we have found the mean and now we will replace it with true so that the null values changes to true value.
# Out:
# 2006.4064433147682

# %%
videogame.Year.fillna(Yearof_mean,inplace=True) #with this function we have replaced the null values to true.

# %%
videogame.isnull().sum() #now we have dealt with the null values of (Year).
# Out:
# Rank             0
# Name             0
# Platform         0
# Year             0
# Genre            0
# Publisher       58
# NA_Sales         0
# EU_Sales         0
# JP_Sales         0
# Other_Sales      0
# Global_Sales     0
# dtype: int64

# %% [markdown]
# #### Univariate Analysis

# %% [markdown]
#  Down below i have tried to find what is the minimum sp and maximum sp in Global sales

# %%
# 1. HISTOGRAM - sns.histplot()
fig, ax = plt.subplots()
sns.histplot(x='Global_Sales', data=videogame)
print("Minimum SP:",videogame['Global_Sales'].min())
print("Maximum SP:",videogame['Global_Sales'].max())
ax.set_xlim(0, 100)
ax.set_ylim(0, 100)
bins=2

plt.show()
# Out:
# Minimum SP: 0.01
# Maximum SP: 82.74

# %%
#here i will take all the varibles and will see its graph accordingly with the growing year's .
# we will only see the graph of numerical varibles by eliminating the object type varible.
# we will run the loop with 'enumarate' function , this function helps in getting multiple varibales evaluation at a time.
cols = 3
rows = 3
num_cols = videogame.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):
#for i in num_cols:    
    ax=fig.add_subplot(rows,cols,i+1)
    
    sns.histplot(x = videogame[col], ax = ax)
    
fig.tight_layout()  
plt.show()

# %% [markdown]
# #KDE ( Kernel Density Estimate) , this is the visualisation technique used to visualise continuos variable (probability density function)
# #Relative to histogram , KDE can produce a plot which is less cluttered and more interpretable especially while drawing multiple distribution.

# %%
 #KDE PLOT - Kernal Density Plot - sns.kdeplot()
sns.kdeplot(x='Global_Sales', data=videogame, hue='Genre')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Density'>

# %%
# with histogram - sns.histplot(kde=TRUE)
sns.histplot(x='Global_Sales', data=videogame, kde=True)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Count'>

# %%
# 4. BOX PLOTS - sns.boxplot()
sns.boxplot(x=videogame['Global_Sales'])
# Out:
# <AxesSubplot:xlabel='Global_Sales'>

# %% [markdown]
# Categorical value(Bivariate) Analysis

# %%
videogame.dtypes #with this function we can find the datatype of categories in our dataset
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
videogame.Genre.value_counts() #here my targert varibale is 'Genre' that which Genre is been focused more by the publishers
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
videogame.Genre.value_counts(normalize=True)
# Out:
# Action          0.199783
# Sports          0.141342
# Misc            0.104772
# Role-Playing    0.089649
# Shooter         0.078925
# Adventure       0.077479
# Racing          0.075250
# Platform        0.053380
# Simulation      0.052235
# Fighting        0.051090
# Strategy        0.041029
# Puzzle          0.035064
# Name: Genre, dtype: float64

# %%
videogame.Genre.value_counts(normalize=True).plot.bar()
plt.show() #here  i have tried to bring u with the same but in form of graphs.

# %%
plt.title("Top 10 Genre in US")
plt.pie(top_500_us_genre , labels=top_500_us_genre.index , autopct = '%1.1f%%', startangle=360)
plt.show()
#In the form of pie chart we can see what percentage the publisher is focusing on which Genre of videogame .

# %% [markdown]
# ## Ploting the relation between year and country sales

# %% [markdown]
# #### Below graph shows the relation between North America sales with respect to the country

# %%
#Here i am comparing the different year sales in North America.
plt.figure(figsize=(16,6))
sns.barplot(x='Year' , y= 'NA_Sales' , data=videogame)
plt.xticks(rotation=90) #here with the function (xticks) it basically sets the angle for the x-axis vlaues.
plt.show()

# %% [markdown]
# #### Ploting the relation between European country sale with respect to the year

# %%
# Here is the comparison between the sales in diffrent year in European country
plt.figure(figsize=(16,6))
sns.barplot(x='Year' , y= 'EU_Sales' , data=videogame)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Plotting the relation between the Japan sales with respect to the year

# %%
#Here is the comparison between the sales in different year in Japan .
plt.figure(figsize=(20,10))
sns.barplot(x='Year' , y='JP_Sales' , data=videogame)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Plotting the replation Between Other sales with respect to the Year

# %%
# Here is the sales of video games in different year in other countries
plt.figure(figsize=(20,10))
sns.barplot(x='Year' , y='Other_Sales' , data=videogame)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Plotting the Relation between Global sale in different year

# %%
plt.figure(figsize=(16,10))
sns.barplot(x='Year' , y='Global_Sales' , data=videogame)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### How many video games has been sold between the Year 2001 and 2012 of all countries and globally?

# %%
print('''Calculating the country and global sales between the year mentioned''')
year_count=[i for i in range (2001,2013)]# here i have mentioned of which year sales i will calculate
count_in_range= videogame.loc[videogame['Year'].isin(year_count)]
# Out:
# Calculating the country and global sales between the year mentioned

# %%
count_in_range
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 6          7                             New Super Mario Bros.       DS
# 7          8                                          Wii Play      Wii
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# How many sales did each country made between the year's 2001 to 2012

# %%
NA_S=sum(count_in_range.NA_Sales)
print('\nTotal sales in North America from year 2001 to 2012 is:' ,round(NA_S), 'Millions')

EU_S=sum(count_in_range.EU_Sales)
print('\nTotal sales in Europe from year 2001 to 2012 is:' ,round(EU_S), 'Millions')

JP_S=sum(count_in_range.JP_Sales)
print('\nTotal sales in Japan from year 2001 to 2012 is:' ,round(JP_S), 'Millions')

Other_S=sum(count_in_range.Other_Sales)
print('\nTotal sales in Other countries from year 2001 to 2012 is:' ,round(Other_S), 'Millions')

Global_S=sum(count_in_range.Global_Sales)
print('\nTotal videogames Global Sale from year 2001 to 2012 is:' ,round(Global_S), 'Millions')
# Out:
# Total sales in North America from year 2001 to 2012 is: 3015 Millions
#
# Total sales in Europe from year 2001 to 2012 is: 1666 Millions
#
# Total sales in Japan from year 2001 to 2012 is: 632 Millions
#
# Total sales in Other countries from year 2001 to 2012 is: 605 Millions
#
# Total videogames Global Sale from year 2001 to 2012 is: 5922 Millions

# %% [markdown]
# #### Show the top platform and publisher in the dataset

# %%
top_platform = videogame.Platform.value_counts().head(15)
top_publisher = videogame.Publisher.value_counts().head(15)
#here i have shown the top 15 platforms and publisher

# %%
top_platform
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# Name: Platform, dtype: int64

# %%
top_publisher
# Out:
# Electronic Arts                           1351
# Activision                                 975
# Namco Bandai Games                         932
# Ubisoft                                    921
# Konami Digital Entertainment               832
# THQ                                        715
# Nintendo                                   703
# Sony Computer Entertainment                683
# Sega                                       639
# Take-Two Interactive                       413
# Capcom                                     381
# Atari                                      363
# Tecmo Koei                                 338
# Square Enix                                233
# Warner Bros. Interactive Entertainment     232
# Name: Publisher, dtype: int64

# %% [markdown]
# Taking the mean,min and max values of global sales

# %%
agg_result = videogame.groupby('Publisher').agg({'Global_Sales':['mean','min','max']})
agg_result 
#above we can see that we have seen the top publisher of the dataset but here we can see the top publisher but considering the mean,min and maximum value.
# Out:
#                              Global_Sales
#                                      mean   min   max
# Publisher
# 10TACLE Studios                  0.036667  0.02  0.06
# 1C Company                       0.033333  0.01  0.05
# 20th Century Fox Video Games     0.388000  0.22  0.79
# 2D Boy                           0.040000  0.04  0.04
# 3DO                              0.281111  0.01  1.28
# ...                                   ...   ...   ...
# id Software                      0.030000  0.03  0.03
# imageepoch Inc.                  0.020000  0.01  0.03
# inXile Entertainment             0.100000  0.10  0.10
# mixi, Inc                        0.860000  0.86  0.86
# responDESIGN                     0.065000  0.04  0.09
#
# [578 rows x 3 columns]

# %% [markdown]
# What are the Genre of the games in the dataset?

# %%
videogame['Genre'].unique()
#with this operation we can see the unique value or cahracter of my dataset which is presnt i the Genre.
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
top_500_us = videogame.sort_values('NA_Sales',ascending=False).head(500)
top_500_us
# Out:
#       Rank                           Name Platform    Year     Genre  \
# 0        1                     Wii Sports      Wii  2006.0    Sports
# 1        2              Super Mario Bros.      NES  1985.0  Platform
# 9       10                      Duck Hunt      NES  1984.0   Shooter
# 5        6                         Tetris       GB  1989.0    Puzzle
# 2        3                 Mario Kart Wii      Wii  2008.0    Racing
# ...    ...                            ...      ...     ...       ...
# 1123  1125                   ESPN NFL 2K5       XB  2004.0    Sports
# 808    810    Spec Ops: Airborne Commando       PS  2002.0   Shooter
# 836    838                  Madden NFL 15      PS4  2014.0    Sports
# 890    892  Mortal Kombat vs. DC Universe     X360  2008.0  Fighting
# 942    944               NCAA Football 06      PS2  2005.0    Sports
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#top_500_eu_genre = top_500_eu.Genre.value_counts()

# %%
plt.figure(figsize=(15,10))
racing_game_list = videogame.loc[videogame['Genre']=='Racing']
sns.barplot(data=racing_game_list , x='Year' , y='Global_Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15,10))
racing_game_list = videogame.loc[videogame['Genre']=='Action']
sns.barplot(data=racing_game_list , x='Year' , y='Global_Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Correlation  Test - Pearson and Spearman's Rank Relation

# %%
# Spearman and Perason correlation gives similar kind of result but they differ with bit with the numbers this happens because, 
# Pearson measure the linear relation between the two variables and spearman measures the monotonic function

# %%
#person and spearman testing for correlation
import matplotlib
from matplotlib import pyplot
FirstSample = videogame[1:30]['Global_Sales']
SecondSample = videogame[1:30]['NA_Sales']

pyplot.plot(FirstSample,SecondSample)
pyplot.show()

# %%
#person and spearman testing for correlation
import matplotlib
from matplotlib import pyplot
FirstSample = videogame[1:30]['Global_Sales']
SecondSample = videogame[1:30]['EU_Sales']

pyplot.plot(FirstSample,SecondSample)
pyplot.show()

# %%
#Spearman Rank Correlation
from scipy.stats import spearmanr
stat, p = spearmanr(FirstSample, SecondSample)

print('stat=%.3f, p=%5f' % (stat, p))
if p > 0.05:
    print('independent samples')
else:
    print('dependent samples')
# Out:
# stat=0.757, p=0.000002
# dependent samples

# %%
#pearson correlation
from scipy.stats import pearsonr
stat, p = pearsonr(FirstSample, SecondSample)

print('stat=%.3f, p=%5f' % (stat, p))
if p > 0.05:
    print('independent samples')
else:
    print('dependent samples')
# Out:
# stat=0.759, p=0.000002
# dependent samples

# %% [markdown]
# Multivariate analysis

# %%
videogame.groupby(by='Genre').agg('mean')[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']]
# Out:
#               NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Genre
# Action        0.264726  0.158323  0.048236     0.056508      0.528100
# Adventure     0.082271  0.049868  0.040490     0.013072      0.185879
# Fighting      0.263667  0.119481  0.103007     0.043255      0.529375
# Misc          0.235906  0.124198  0.061967     0.043312      0.465762
# Platform      0.504571  0.227573  0.147596     0.058228      0.938341
# Puzzle        0.212680  0.087251  0.098471     0.021564      0.420876
# Racing        0.287766  0.190865  0.045388     0.061865      0.586101
# Role-Playing  0.219946  0.126384  0.236767     0.040060      0.623233
# Shooter       0.444733  0.239137  0.029221     0.078389      0.791885
# Simulation    0.211430  0.130773  0.073472     0.036355      0.452364
# Sports        0.291283  0.160635  0.057702     0.057532      0.567319
# Strategy      0.100881  0.066579  0.072628     0.016681      0.257151

# %%
videogame_Action=videogame.loc[videogame['Genre']=='Action']
videogame_Shooter=videogame.loc[videogame['Genre']=='Shooter']
videogame_Sports=videogame.loc[videogame['Genre']=='Sports']
videogame_Platform=videogame.loc[videogame['Genre']=='Platform']
videogame_Misc=videogame.loc[videogame['Genre']=='Misd']
videogame_Racing=videogame.loc[videogame['Genre']=='Racing']
videogame_Fighting=videogame.loc[videogame['Genre']=='Fighting']
videogame_Simulation=videogame.loc[videogame['Genre']=='Simulation']
videogame_Puzzle=videogame.loc[videogame['Genre']=='Puzzle']
videogame_Strategy=videogame.loc[videogame['Genre']=='Strategy']
videogame_Adventure=videogame.loc[videogame['Genre']=='Adventure']

# %%
videogame_Action=videogame.loc[videogame['Genre']=='Action']
videogame_Shooter=videogame.loc[videogame['Genre']=='Shooter']
videogame_Sports=videogame.loc[videogame['Genre']=='Sports']
videogame_Platform=videogame.loc[videogame['Genre']=='Platfrom']
videogame_Misc=videogame.loc[videogame['Genre']=='Misc']
videogame_Racing=videogame.loc[videogame['Genre']=='Racing']
videogame_Fighting=videogame.loc[videogame['Genre']=='Fighting']
videogame_Simulation=videogame.loc[videogame['Genre']=='Simulation']
videogame_Puzzle=videogame.loc[videogame['Genre']=='Puzzle']
videogame_Strategy=videogame.loc[videogame['Genre']=='Strategy']
videogame_Adventure=videogame.loc[videogame['Genre']=='Adventure']

# %%
sns.pairplot(videogame,hue='Genre',height=2)

# %% [markdown]
# Here in this multivariate analysis i have analyse my graph on a way considering the multiple target variable of my dataset. We will see here the positive correlation  , probability density function , scatter plot and the histplot . We can see all the graph all at a time because i have used the ( Pairlplot ) fuction , this fuction helps in getting all the plot in one analysis considering sutability of graph analyse at the pair or with the variables
